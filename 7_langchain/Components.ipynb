# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI

llm=ChatOpenAI(model="gpt-4o-mini")

def get_response(prompt):
    response = llm.invoke(prompt)
    return response.content

# %%
from langchain.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an expert in AI engineering. Provide me answers based on the question."),
        ("user", "{input}"),
    ]
)

# %%
chain = prompt | llm 
response = chain.invoke(input="What is LangSmith good for?")
print(response.content)
# Out:
# LangSmith is a tool designed to assist developers and teams in building, managing, and deploying AI applications effectively. It offers functionalities that enhance the development process, such as:
#
# 1. **Versioning and Collaboration**: LangSmith allows for better version control of AI models, facilitating collaboration among teams by providing a shared space for managing changes and tracking progress.
#
# 2. **Model Management**: The platform aids in organizing and managing machine learning models, including monitoring their performance, fine-tuning, and retraining.
#
# 3. **Code Generation**: LangSmith can assist in generating boilerplate code and facilitating the integration of AI models into applications, reducing the amount of manual coding required.
#
# 4. **Testing and Validation**: It provides tools for testing AI applications, ensuring that models behave as expected and meet the criteria set forth by the development team.
#
# 5. **Documentation**: LangSmith helps in generating documentation automatically, which is crucial for maintaining clear communication in AI projects and ensuring that new team members can onboard quickly.
#
# 6. **Integration Support**: The tool often supports integration with popular development frameworks and tools, making it easier for teams to incorporate AI functionalities into their existing workflows.
#
# By utilizing LangSmith, AI engineers and developers can optimize the AI development lifecycle, improve workflow efficiency, and create more robust and reliable AI applications.

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()
chain = prompt | llm | output_parser
response = chain.invoke(input="What is LangSmith good for?")
print(response)
# Out:
# LangSmith is a tool primarily designed for developers and data scientists working with natural language processing (NLP) applications. It offers features that facilitate the development, testing, and deployment of language models and related projects. Key capabilities of LangSmith include:
#
# 1. **Model Training:** LangSmith helps streamline the process of training language models, providing features for data preparation, model configuration, and fine-tuning.
#
# 2. **Experiment Tracking:** It allows users to track experiments and results, making it easier to compare different model versions and understand performance metrics.
#
# 3. **Collaboration:** LangSmith supports collaboration among team members, enabling multiple users to work on projects simultaneously and share insights and results.
#
# 4. **Integration:** The tool often integrates with various data sources and machine learning frameworks, making it easier to incorporate into existing workflows.
#
# 5. **Monitoring and Evaluation:** LangSmith can be used to monitor the performance of deployed language models and evaluate their effectiveness against defined metrics.
#
# 6. **Documentation and Versioning:** It assists in maintaining proper documentation of language model iterations and changes, which is crucial for reproducibility and governance in AI projects.
#
# Overall, LangSmith aims to make the development process for language models more efficient, transparent, and collaborative, facilitating better outcomes in NLP applications.
